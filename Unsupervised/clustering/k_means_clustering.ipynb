# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_excel('Research data.xlsx')
X = dataset.iloc[:, :].values

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ## Training the K-Means model on the dataset

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
print(y_kmeans)
# Out:
# [3 3 3 ... 1 1 1]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.12767647e-04 3.94686764e-04 1.69809282e-02 4.12024790e-02
#   1.53176054e-03 1.29682794e-03 1.24561263e-02 2.03451630e-03
#   9.67922303e-04 1.88181011e-02 4.46371936e-04 3.21857659e-03
#   3.36423480e-03 1.59754167e-04 7.00099142e-04 3.47935177e-02
#   1.19674665e-02 7.84674877e-04 2.01102304e-03 2.22575143e-02
#   3.38302941e-04 2.15405479e+02]
#  [2.53288156e-03 3.41751235e-03 1.30483042e-02 1.42125117e-02
#   5.76428762e-02 5.95039391e-02 2.86169716e-02 9.97337762e-02
#   8.61680465e-03 9.87698625e-03 4.08933102e-04 1.74547670e-02
#   1.36032848e-02 2.25330485e-04 8.92976365e-03 5.37872213e-03
#   8.56255842e-03 6.92682601e-04 2.16984911e-04 6.63473094e-04
#   4.49409133e-03 1.33288950e+02]
#  [6.05229180e-05 1.34495373e-04 4.29712718e-03 3.44308156e-03
#   7.39724553e-05 1.27770605e-04 1.58704541e-03 2.68990746e-05
#   3.49687971e-04 9.28018076e-04 5.85054874e-04 1.68119217e-04
#   2.19899935e-03 3.81294383e-03 2.03088014e-03 1.27098128e-03
# ...

# %% [markdown]
# ## Visualising the clusters

# %%
plt.scatter(X[y_kmeans == 0, 1], X[y_kmeans == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 1], X[y_kmeans == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 1], X[y_kmeans == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 1], X[y_kmeans == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering Cell 2')
plt.xlabel('Patterns')
plt.ylabel('Positions')
plt.legend()
plt.show()

# %%
plt.scatter(X[y_kmeans == 0, 9], X[y_kmeans == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 9], X[y_kmeans == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 9], X[y_kmeans == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 9], X[y_kmeans == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering Cell 10')
plt.xlabel('Patterns')
plt.ylabel('Positions')
plt.legend()
plt.show()

# %%
plt.scatter(X[y_kmeans == 0, 20], X[y_kmeans == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 20], X[y_kmeans == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 20], X[y_kmeans == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 20], X[y_kmeans == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering cell 21')
plt.xlabel('Patterns')
plt.ylabel('Positions')
plt.legend()
plt.show()
